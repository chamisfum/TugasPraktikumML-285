# %%
from tensorflow.keras.models import load_model
chosen_model = '100%_S2'
model_list = {'100%_S2':'/content/drive/MyDrive/Unknown Files/100%_S2.h5', 
              'model_gastric':'/content/drive/MyDrive/Unknown Files/model_gastric.h5', 
             }
model = load_model(model_list[chosen_model]) if chosen_model in model_list else load_model(model_list['model_gastric'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              (None, 224, 224, 64)      1792
# _________________________________________________________________
# batch_normalization (BatchNo (None, 224, 224, 64)      256
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 112, 112, 128)     73856
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 112, 112, 128)     512
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 56, 56, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 56, 56, 256)       295168
# ...
